# %% [markdown]
# # pandas Data Load
# pandas Documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html
#
# Wes McKinney "Python for Data Analysis" Chapter 6:
# https://learning.oreilly.com/library/view/python-for-data/9781491957653/ch06.html

# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np
from IPython.display import Image
plt.rc('figure', figsize=(10, 6))
# %matplotlib inline

# %% [markdown]
# ### pandas IO Tools
# 1. create your own: [10min to pandas](https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html)
# 2. [pandas read_csv()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html):  Read a comma-separated values (csv) file into DataFrame.
# 3. DataSets in Python: [Article by Sergiy Koleshnikov](https://kolesnikov.ga/Datasets_in_Python/)  ***Statsmodels***, ***scikit-learn***, and ***seaborn*** provide convenient access to a large number of datasets of different sizes and from different domains.
# 4. [pandas read_fwf](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_fwf.html): Read a table of fixed-width formatted lines into DataFrame.
# 5. [pandas read_clipboard](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_clipboard.html): Read text from clipboard and pass to read_csv.
# 6. [pandas read_excel](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_excel.html#pandas.read_excel): Read an Excel file into a pandas DataFrame.  Support both xls and xlsx file extensions from a local filesystem or URL. Support an option to read a single sheet or a list of sheets.
# 7. [pandas read_hdf](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_hdf.html#pandas.read_hdf): Read Hierarchical Data Format File (.hdf file extension).
# 8. [pandas read_html](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_html.html): Read HTML tables into a list of DataFrame objects.
# 9. [pandas read_json](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_json.html): Convert a JSON string to pandas object, Series or DataFrame.
# 10. [pandas read_pickle](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_pickle.html): Load pickled pandas object (or any object) from file.  Pickling is a way to convert a python object (list, dict, etc.) into a character stream.
# 11. [pandas read_sas](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_sas.html): Read SAS files stored as either XPORT or SAS7BDAT format files.
# 12. [pandas read_sql](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_sql.html#pandas.read_sql): Read SQL query or database table into a DataFrame.
# 13. [pandas read_stata](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_stata.html): Read Stata file (with extension .dta) into DataFrame.  Stata 1.0 was released in 1985 for the IBM PC.
# 14. [pandas read_feather](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_feather.html): Load a feather-format object from the file path.  Feather is a fast, lightweight, and easy-to-use binary file format for storing data frames.
# 15. [pandas data-reader](https://pandas-datareader.readthedocs.io/en/latest/remote_data.html): Extract data from various Internet sources into a pandas DataFrame.
# 16. [GapMinder Global Facts](https://www.gapminder.org)
# 17. [Socrata API](https://dev.socrata.com)
#
# ### Safari Examples of Data Load:
# https://learning.oreilly.com/library/view/python-data-analytics/9781484239131/html/336498_2_En_5_Chapter.xhtml
#
# https://learning.oreilly.com/library/view/data-visualization-with/9781491920565/ch08.html
#
# How to access Safari: https://blogs.baruch.cuny.edu/newmanreference/2018/11/19/new-database-safari/
#
# ### Data Sources
# Baruch College Open Data Sources: https://guides.newman.baruch.cuny.edu/opendata
#
# Popular Project Datasets: https://perso.telecom-paristech.fr/eagan/class/igr204/datasets
#
# Project Open Data: https://project-open-data.cio.gov
#
# GitHub Datasets: https://github.com/awesomedata/awesome-public-datasets
#
# NYC Open Data: https://opendata.cityofnewyork.us
#
# State of NY Open Data: https://data.ny.gov
#
# US Government's Open Data: https://www.data.gov
#
# U.S. Bureau of Labor Statistics: https://www.bls.gov
#
# Centers for Disease Control and Prevention: https://www.cdc.gov
#
# Medicare data: https://data.medicare.gov
#
# Principles of Econometrics (textbook data): http://principlesofeconometrics.com
#
# Pitney Bowes: https://www.pitneybowes.com/us/data/sdm.html
#
# FiveThirtyEight: https://data.fivethirtyeight.com
#
# European stats: https://ec.europa.eu/eurostat
#
# World stats: https://www.worldometers.info
#
# Data.gov: https://catalog.data.gov/dataset
#
# FDIC: https://www.fdic.gov
#
# Gun Violence Archive: https://www.gunviolencearchive.org
#
# Wikipedia example - Firearm death rates in the US by State:
# https://en.wikipedia.org/wiki/Firearm_death_rates_in_the_United_States_by_state
#
# Airbnb: http://insideairbnb.com/get-the-data.html
#
# NFL stats from CBS: https://www.cbssports.com/nfl/stats
#
# Basketball: https://www.basketball-reference.com
#
# ESPN: https://www.espn.com
#
# Environmental information from NCDC: https://www.ncdc.noaa.gov
#
# Social Security Administration: https://www.ssa.gov
#
# Global industry trends: https://www.nationmaster.com
#
# Cryptocurrency data: https://min-api.cryptocompare.com
#
# Yahoo!  Finance: https://finance.yahoo.com
#
# Outdoor travel blog: https://www.atlasandboots.com
#
# Popular Statistics: https://www.statista.com
#
# SAS Public DataSets: https://semanticommunity.info/Data_Science/SAS_Public_Data_Sets

# %% [markdown]
# ### Example: Fixed Format File
# https://www.oracle.com/webfolder/technetwork/data-quality/edqhelp/Content/introduction/getting_started/configuring_fixed_width_text_file_formats.htm

# %%
Image("img/Ch06 Fixed-format.gif")

# %% [markdown]
# ## 1. Create Your Own

# %%
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
s
# Out:
# 0     0.087054
# 10    0.471096
# 20    0.800156
# 30    0.271828
# 40   -1.590883
# 50   -2.324350
# 60   -1.888641
# 70   -3.650205
# 80   -2.776199
# 90   -2.903477
# dtype: float64

# %%
s.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(0),
                  columns=['A', 'B', 'C', 'D'],
                  index=np.arange(0, 100, 10))
df
# Out:
#            A         B         C         D
# 0   1.080654 -1.173718  1.056741  0.449877
# 10  2.953298 -0.790586  0.230799  1.930833
# 20  3.278311  1.154767 -1.071806  3.744462
# 30  1.798920  1.833566 -1.199186  3.127503
# 40  2.918390  0.257510 -1.788481  4.813456
# 50  3.558222 -0.495162 -1.685334  3.943886
# 60  4.128331 -1.942996 -2.696560  3.719006
# 70  5.447516 -3.425312 -3.919879  2.858404
# 80  5.262979 -3.619453 -3.979568  2.292705
# 90  3.672772 -4.717844 -5.557249  2.576594

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 2. pandas read_csv()
#
# Popular baby names: https://catalog.data.gov/dataset/most-popular-baby-names-by-sex-and-mothers-ethnic-group-new-york-city-8c742
#
#
# Download the examples and datasets from Wes McKinney on GitHub: https://github.com/wesm/pydata-book

# %%
tips = pd.read_csv('data/tips.csv')
tips.head()
# Out:
#    total_bill   tip smoker  day    time  size
# 0       16.99  1.01     No  Sun  Dinner     2
# 1       10.34  1.66     No  Sun  Dinner     3
# 2       21.01  3.50     No  Sun  Dinner     3
# 3       23.68  3.31     No  Sun  Dinner     2
# 4       24.59  3.61     No  Sun  Dinner     4

# %% [markdown]
# ## 3. seaborn example

# %%
import seaborn as sns

# To view all the available data sets 
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### 3B. For statsmodels datasets, install statsmodels
# If Anaconda installation does not include statsmodels:
# ```python
# conda install -c conda-forge statsmodels
# ```
# Smoking and lung cancer stats in China by city.

# %%
import statsmodels.api as sm
smoking = sm.datasets.china_smoking
dataset = smoking.load_pandas()
df = dataset.data
df.head()
# Out:
#           smoking_yes_cancer_yes  smoking_yes_cancer_no  \
# Location
# Beijing                      126                    100
# Shanghai                     908                    688
# Shenyang                     913                    747
# Nanjng                       235                    172
# Harbin                       402                    308
#
#           smoking_no_cancer_yes  smoking_no_cancer_no
# Location
# Beijing                      35                    61
# Shanghai                    497                   807
# Shenyang                    336                   598
# Nanjng                       58                   121
# Harbin                      121                   215

# %% [markdown]
# ## 5. Reading from clipboard

# %% [markdown]
# Financial data from http://www.optionistics.com/quotes/stock-option-chains/SPY
# Shows SPY option chain data for call expiring call options.

# %%
options_df = pd.read_clipboard()
options_df.head()
# Out:
#   Symbol   Bid   Ask  Price  TPrice  Volume     OI  NS     Strike Symbol.1  \
# 0    SPY  1.64  1.83   1.74     0.0   11732   5587   W        356      SPY
# 1    SPY  0.77  0.91   0.87     0.0   14925   6659   W        357      SPY
# 2    SPY  0.19  0.21   0.20     0.0   55931  11164   W        358      SPY
# 3    SPY  0.02  0.03   0.03     0.0  104486  10336   W        359      SPY
# 4    SPY  0.01  0.02   0.01     0.0  198227  27472   W        360      SPY
#
#    Bid.1  Ask.1  Price.1  TPrice.1  Volume.1   OI.1 NS.1  .1
# 0   0.02   0.03     0.02       0.0    140157  17190    W
# 1   0.06   0.07     0.07       0.0    201062  18139    W
# 2   0.46   0.47     0.47       0.0    235478  22835    W
# 3   1.22   1.35     1.29       0.0    187261  21437    W
# 4   2.27   2.30     2.30       0.0    309656  53942    W

# %% [markdown]
# ## 8.  Read HTML
# Textbook example
#
# Python has many libraries for reading and writing data in the ubiquitous HTML and XML formats. Examples include lxml, Beautiful Soup, and html5lib. While lxml is comparatively much faster in general, the other libraries can better handle malformed HTML or XML files.
#
# pandas has a built-in function, read_html, which uses libraries like lxml and Beautiful Soup to automatically parse tables out of HTML files as DataFrame objects. To show how this works, I downloaded an HTML file (used in the pandas documentation) from the United States FDIC government agency showing bank failures.
#
# The pandas.read_html function has a number of options, but by default it searches for and attempts to parse all tabular data contained within <table> tags. The result is a list of DataFrame objects:

# %%
# to install html5lib: 
# !pip install html5lib
my_list = pd.read_html('data/fdic_failed_bank_list.html')
type(my_list)
# Out:
# list

# %%
len(my_list)
# Out:
# 1

# %%
failures = my_list[0]
failures.head()
# Out:
#                       Bank Name             City  ST   CERT  \
# 0                   Allied Bank         Mulberry  AR     91
# 1  The Woodbury Banking Company         Woodbury  GA  11297
# 2        First CornerStone Bank  King of Prussia  PA  35312
# 3            Trust Company Bank          Memphis  TN   9956
# 4    North Milwaukee State Bank        Milwaukee  WI  20364
#
#                  Acquiring Institution        Closing Date       Updated Date
# 0                         Today's Bank  September 23, 2016  November 17, 2016
# 1                          United Bank     August 19, 2016  November 17, 2016
# 2  First-Citizens Bank & Trust Company         May 6, 2016  September 6, 2016
# 3           The Bank of Fayette County      April 29, 2016  September 6, 2016
# 4  First-Citizens Bank & Trust Company      March 11, 2016      June 16, 2016

# %% [markdown]
# ### Best CD rates
# from https://www.bankrate.com/cd-left/
# The banks with best CD (Certificate of Deposit) Rates of September 2019.  We can compare their 1-year APY, 3-year APY and 5-year APY.

# %%
bank_rates_df = pd.read_html("data/bankrate.html")
bank_rates_df[0].head()
# Out:
#                  Bank 1-year APY 3-year APY 5-year APY Minimum Deposit
# 0  Goldman Sachs Bank      2.25%      2.35%      2.45%            $500
# 1      Synchrony Bank      2.25%      2.35%      2.45%          $2,000
# 2            Barclays      2.25%      2.20%      2.20%              $0
# 3     Comenity Direct      2.30%      2.40%      2.50%          $1,500
# 4     Citizens Access      2.25%      2.35%      2.45%          $5,000

# %% [markdown]
# List of manufacturers by motor vehicle production: https://en.wikipedia.org/wiki/List_of_manufacturers_by_motor_vehicle_production

# %%
motor_df = pd.read_html("https://en.wikipedia.org/wiki/List_of_manufacturers_by_motor_vehicle_production")
motor_df[0].head()
# Out:
#     0                                                  1
# 0 NaN  This article needs to be updated. Please help ...

# %% [markdown]
# Cocktails and their ingredients from http://www.hotalingandco.com/cocktails/

# %%
cocktails_df = pd.read_html("http://www.hotalingandco.com/cocktails/")[0]
cocktails_df.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [54], in <cell line: 1>()
# ----> 1 cocktails_df = pd.read_html("http://www.hotalingandco.com/cocktails/")[0]
#       2 cocktails_df.head()
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas/io/html.py:1113, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
# ...

# %% [markdown]
# # 12. Read SQL query or database table into a DataFrame.
#
#
# **SQLite** is a database engine written in the C programming language. It is not a standalone app; rather, it is a library that software developers embed in their apps. As such, it belongs to the family of embedded databases. It is the most widely deployed database engine, as it is used by several of the top web browsers, operating systems, mobile phones, and other embedded systems.
#
# Learn more about Sqlite DB Engine: https://en.wikipedia.org/wiki/SQLite

# %%
from sqlite3 import connect
conn = connect(':memory:')
df = pd.DataFrame(data=[[0, '10/11/12'], [1, '12/11/10']], 
                  columns=['int_column', 'date_column'])
df.to_sql(abs'test_data', conn)
df.to_sql?

# %%
pd.read_sql('SELECT int_column, date_column FROM test_data', conn)

# %% [markdown]
# ## 15. pandas datareader
#
# Read Yahoo! Finance SPY datapoints.
# Article with more examples: https://learndatasci.com/tutorials/python-finance-part-yahoo-finance-api-pandas-matplotlib/

# %%
from pandas_datareader import data

start_date = '2019-09-09'
end_date = '2019-09-13'

SPY_data = data.DataReader('SPY', 'yahoo', start_date, end_date)
SPY_data.head()

# %% [markdown]
# Quandl Cryptocurrency
# https://www.quandl.com/databases/BICC/documentation?utm_source=quandlcomms&utm_medium=email&utm_campaign=BICC_2019q3

# %% [markdown]
# ## 16. GapMinder Global Facts
# Gapminder is an independent educational non-proﬁt ﬁghting global misconceptions.
# https://www.gapminder.org
#
# https://github.com/jstaf/gapminder
#
# To install:
# ```python
# pip install gapminder
# ```

# %%
from gapminder import gapminder
gapminder.head()
